# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/work on it /Pratice wine/winequality.csv"

# %%
wine_data=pd.read_csv(path)

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
pip install ydata_profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.2 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=1a4d9803628d490ac1a5bcf04d5a7c3b386c10077f1c00b1b5ae1904b07ebd47
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(wine_data)
profile.to_file("output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
wine_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data_col=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
 'pH', 'sulphates', 'alcohol', 'quality']

# %% [markdown]
# 1. **Fixed acidity:** It indicates the amount of tartaric acid in wine and is measured in g/dm3.
# 2. **Volatile acidity:** It indicates the amount of acetic acid in the wine. It is measured in g/dm3.
# 3. **Citric acid:** It indicates the amount of citric acid in the wine. It is also measured in g/dm3.
# 4. **Residual sugar:** It indicates the amount of sugar left in the wine after the fermentation process is done. It is also measured in g/dm3.
# 5. **Free sulfur dioxide:** It measures the amount of sulfur dioxide (SO2) in free form. It is also measured in g/dm3.
# 6. **Total sulfur dioxide:** It measures the total amount of SO2 in the wine.This chemical works as an antioxidant and antimicrobial agent.
# 7. **Density:** It indicates the density of the wine and is measured in g/dm3.
# 8. **pH:** It indicates the pH value of the wine. The range of value is between 0 to 14.0,which indicates very high acidity, and 9. indicates basic acidity.
# 10. **Sulphates:** It indicates the amount of potassium sulphate in the wine. It is also measured in g/dm3.
# 11. **Alcohol:** It indicates the alcohol content in the wine.
# 12. **Quality:** It indicates the quality of the wine, which is ranged from 1 to 10. Here, the higher the value is, the better the wine.

# %%
wine_data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
wine_data.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         6497.0    7.215307   1.296434  3.80000   6.40000
# volatile acidity      6497.0    0.339666   0.164636  0.08000   0.23000
# citric acid           6497.0    0.318633   0.145318  0.00000   0.25000
# residual sugar        6497.0    5.443235   4.757804  0.60000   1.80000
# chlorides             6497.0    0.056034   0.035034  0.00900   0.03800
# free sulfur dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total sulfur dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6497.0    3.218501   0.160787  2.72000   3.11000
# sulphates             6497.0    0.531268   0.148806  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# quality               6497.0    5.818378   0.873255  3.00000   5.00000
#
# ...

# %%
plt.figure(figsize=(14,9))
sns.countplot(x='quality',data=wine_data)
plt.title("The majority of wine is of medium quality")
plt.xlabel("Wine Qulality")
plt.ylabel("Count")
plt.grid()
plt.show()

# %%
#Lets find highly correlated columns form wine database

# %%
plt.figure(figsize=(14,9))
sns.pairplot(wine_data)
new_var = plt.title("Correlation between different columns of Wine Dataset")
new_var
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plt.figure(figsize=(14,9))
sns.heatmap(wine_data.corr(), annot=True, fmt='.2f', linewidths=2)
plt.title("Correlation between different columns of Wine Dataset")
# Out:
# Text(0.5, 1.0, 'Correlation between different columns of Wine Dataset')

# %%
# Negative correlated data : density , total sulfur dioxide , chlorides , residual sugar , velocity acidity , fixed acidity
# Positive correlatted data: quality , alcohol , sulphates , ph , free sulfur dioxide , citric acid

# %%
sns.distplot(wine_data['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.boxplot(x='quality', y='alcohol', data = wine_data)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.jointplot(x='alcohol',y='pH',data=wine_data, kind='reg')

# %%
fig = wine_data.hist(bins=15, color='fuchsia', edgecolor='darkmagenta',
linewidth=1.0, xlabelsize=10, ylabelsize=10, xrot=45, yrot=0,
figsize=(10,9), grid=False)
plt.tight_layout(rect=(0, 0, 1.5, 1.5))

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')
xscale = wine_data['residual sugar']
yscale = wine_data['free sulfur dioxide']
zscale = wine_data['total sulfur dioxide']
ax.scatter(xscale, yscale, zscale, s=50, alpha=0.6, edgecolors='w')
ax.set_xlabel('Residual Sugar')
ax.set_ylabel('free sulfur dioxide')
ax.set_zlabel('Total sulfur dioxide')
plt.show()

# %%
wine_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(10, 10))
plt.scatter(x = wine_data['fixed acidity'],
 y = wine_data['free sulfur dioxide'],
 s = wine_data['total sulfur dioxide'] *2 ,
 alpha=0.4,
 edgecolors='w')
plt.xlabel('Fixed Acidity')
plt.ylabel('free sulfur dioxide')
plt.title('Wine free sulfur dioxide Content - Fixed Acidity - total sulfur dioxide', y=1.05)
# Out:
# Text(0.5, 1.05, 'Wine free sulfur dioxide Content - Fixed Acidity - total sulfur dioxide')

# %%
lower_acceptable_value=wine_data['quality'].quantile(0.02)
upper_acceptable_value=wine_data['quality'].quantile(0.98)
print(f"lower_acceptable_value {lower_acceptable_value}")
print(f"upper_acceptable_value {upper_acceptable_value}")
# Out:
# lower_acceptable_value 4.0
# upper_acceptable_value 8.0

# %%
wine_data.query("quality >= @upper_acceptable_value")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9             0.350         0.46             3.6      0.078
# 278            10.3             0.320         0.45             6.4      0.073
# 390             5.6             0.850         0.05             1.4      0.045
# 440            12.6             0.310         0.72             2.2      0.072
# 455            11.3             0.620         0.67             5.2      0.086
# ...             ...               ...          ...             ...        ...
# 6364            5.2             0.300         0.34             1.5      0.038
# 6365            6.4             0.320         0.25             5.0      0.055
# 6385            4.4             0.320         0.39             4.3      0.030
# 6386            3.9             0.225         0.40             4.2      0.030
# 6401            5.8             0.280         0.34             2.2      0.037
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=wine_data.drop(["quality"],axis=1)
y=wine_data["quality"]
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=1)
print(f"x_train {x_train.shape}")
print(f"x_test {x_test.shape}")
print(f"y_train {x_train.shape}")
print(f"y_test {x_test.shape}")
# Out:
# x_train (5197, 11)
# x_test (1300, 11)
# y_train (5197, 11)
# y_test (1300, 11)

# %%
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()
LR_model
# Out:
# LinearRegression()

# %%
LR_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR_model.predict(x_test)
y_pred
# Out:
# array([5.64817905, 5.48479202, 5.52312899, ..., 5.25814207, 5.30322797,
#        6.16281978])

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse= sqrt(mean_squared_error(y_test,y_pred))
rmse
# Out:
# 0.726937862705743

# %%
from sklearn.metrics import r2_score

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.2735623916315928

# %%
n = len(y_test)

# %%
p = x.shape[1]

# %%
# Calculate adjusted R2
Adj_R2 = 1 - (1 - R2) * (n - 1) / (n - p - 1)

# %%
Adj_R2
# Out:
# 0.26735834373403655

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
select_model=[LinearRegression(),
              DecisionTreeRegressor(),
              RandomForestRegressor(),
              SVR(),
              KNeighborsRegressor(),
              ]

# %%
rmse=[]
r2s=[]
for model in select_model:
  model.fit(x_train,y_train)
  y_pred=model.predict(x_test)
  rmse.append(sqrt(mean_squared_error(y_test,y_pred)))
  rs=r2_score(y_test,y_pred)
  r2s.append(rs)

print(rmse)
print(r2s)
# Out:
# [0.726937862705743, 0.825553427428208, 0.6105957998293394, 0.7839562051711132, 0.8015369850864891]
# [0.2735623916315928, 0.06309812090898526, 0.48747935326276615, 0.15513495076064576, 0.11681664851375217]

# %%
results=pd.DataFrame(data=[rmse,r2s],columns=["LR","DTR","RFR","SVR","KNR"],index=["RMSE","R2Score"])

# %%
results
# Out:
#                LR       DTR       RFR       SVR       KNR
# RMSE     0.726938  0.825553  0.610596  0.783956  0.801537
# R2Score  0.273562  0.063098  0.487479  0.155135  0.116817

# %%
# @title Comparison of Regression Model Performance

import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
models = ['LR', 'DTR', 'RFR', 'SVR', 'KNR']
values = [0.2735623916315928, 0.06309812090898526, 0.48747935326276615, 0.15513495076064576, 0.11681664851375217]

plt.figure(figsize=(10, 6))
plt.bar(models, values, color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel('Regression Model')
plt.ylabel('Value')
plt.title('Comparison of Regression Model Performance')
# Out:
# Text(0.5, 1.0, 'Comparison of Regression Model Performance')
